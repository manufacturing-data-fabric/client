# %% [markdown]
# # Starting the connector instances

# %% [markdown]
# ## I) Functionality Demonstration: The single Connector
#
# A single OPC UA server is running with an opc ua interface. When running the connector, one can clearly see the browsing of the OPC UA servers variable within the connector and the identification of relevant variables to display in the central Knowledge Graph.

# %%
import os
import sys

# Adjust depending on your folder structure — go up to project root
sys.path.append(os.path.abspath(".."))
os.chdir("..")
# !python -m modules.connector_opcua

# %% [markdown]
# ## II) Scalability Demonstration: Three mock OPC UA machinery
#
# A simulation is already running three different mock machinery with OPC UA interfaces, each representing a different machine on a factory floor:
#
# - **`Assembly Station`**
#   A robotic assembly unit with conveyor status, sensors, and operation state.
#
# - **`CNC Milling Machine`**
#   A CNC machine exposing spindle speed, tool position, and temperature data.
#
# - **`Injection Molding Machine`**
#   A molding machine with variables like mold temperature, cycle time, and fill level.
#
# Each Connector is connecting with the OPC UA data sources, and streams realistic sensor data — ideal for testing IIoT integration and semantic data processing.

# %%
import os
import sys

# Adjust depending on your folder structure — go up to project root
sys.path.append(os.path.abspath(".."))
os.chdir("..")
# %run scripts/run_all_connectors.py
# Out:
# Starting connector for assembly_station...
# Starting connector for cnc_milling...
# Starting connector for injection_molding...
# Connectors running. Press Ctrl+C to stop.
# 2025-04-15 15:12:36 - OPCUA - INFO - Initializing OPCUA Client
# 2025-04-15 15:12:36 - OPCUA - INFO - Initializing OPCUA Client
# 2025-04-15 15:12:36 - OPCUA - INFO - Initializing OPCUA Client
# 2025-04-15 15:12:36 - ModuleOPCUA - INFO - Listening on request.ModuleOPCUA.assembly_station
# 2025-04-15 15:12:36 - ModuleOPCUA - INFO - Listening on request.ModuleOPCUA.injection_molding
# 2025-04-15 15:12:36 - ModuleOPCUA - INFO - Listening on request.ModuleOPCUA.cnc_milling
# 2025-04-15 15:12:36 - asyncua.client.client - INFO - connect
# 2025-04-15 15:12:36 - asyncua.client.client - INFO - connect
# 2025-04-15 15:12:36 - asyncua.client.client - INFO - connect
# 2025-04-15 15:12:36 - asyncua.client.ua_client.UaClient - INFO - opening connection
# ...
